# %% [markdown]
# # Building a local Knowledge Graph RAG with Neo4j, LangChain, and Ollama

# %% [markdown]
# ## Preliminary:
# ### Installs

# %%
# !python -V
# !pip install -U -r requirements.txt
# Out:
# Python 3.12.3
# Requirement already satisfied: langchain==1.2.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: langchain-core==1.2.2 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: langchain-classic==1.0.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: langchain-community==0.4.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (0.4)
# Requirement already satisfied: langchain-text-splitters==1.0.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: langchain-experimental==0.4.1 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (0.4.1)
# Requirement already satisfied: langchain-neo4j==0.6.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (0.6.0)
# Requirement already satisfied: langchain-ollama==1.0.1 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: neo4j==5.25.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (5.25.0)
# Requirement already satisfied: wikipedia==1.4.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (1.4.0)
# Requirement already satisfied: python-dotenv==1.0.1 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (1.0.1)
# Requirement already satisfied: pydantic<3 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (2.12.5)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain==1.2.0->-r requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-core==1.2.2->-r requirements.txt (line 3)) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-core==1.2.2->-r requirements.txt (line 3)) (0.5.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-core==1.2.2->-r requirements.txt (line 3)) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-core==1.2.2->-r requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-core==1.2.2->-r requirements.txt (line 3)) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-core==1.2.2->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-core==1.2.2->-r requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-classic==1.0.0->-r requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-classic==1.0.0->-r requirements.txt (line 4)) (2.0.45)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-community==0.4.0->-r requirements.txt (line 7)) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-community==0.4.0->-r requirements.txt (line 7)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-community==0.4.0->-r requirements.txt (line 7)) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-community==0.4.0->-r requirements.txt (line 7)) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-community==0.4.0->-r requirements.txt (line 7)) (2.3.5)
# Requirement already satisfied: neo4j-graphrag<2.0.0,>=1.9.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-neo4j==0.6.0->-r requirements.txt (line 10)) (1.10.1)
# Requirement already satisfied: pytz in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from neo4j==5.25.0->-r requirements.txt (line 14)) (2025.2)
# Requirement already satisfied: ollama<1.0.0,>=0.6.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langchain-ollama==1.0.1->-r requirements.txt (line 11)) (0.6.1)
# Requirement already satisfied: beautifulsoup4 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from wikipedia==1.4.0->-r requirements.txt (line 15)) (4.14.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from pydantic<3->-r requirements.txt (line 17)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from pydantic<3->-r requirements.txt (line 17)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from pydantic<3->-r requirements.txt (line 17)) (0.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.0->-r requirements.txt (line 7)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.0->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.0->-r requirements.txt (line 7)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.0->-r requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.0->-r requirements.txt (line 7)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.0->-r requirements.txt (line 7)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.0->-r requirements.txt (line 7)) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.0->-r requirements.txt (line 7)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.0->-r requirements.txt (line 7)) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core==1.2.2->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain==1.2.0->-r requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain==1.2.0->-r requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain==1.2.0->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain==1.2.0->-r requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain==1.2.0->-r requirements.txt (line 2)) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain==1.2.0->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain==1.2.0->-r requirements.txt (line 2)) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core==1.2.2->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core==1.2.2->-r requirements.txt (line 3)) (0.25.0)
# Requirement already satisfied: anyio in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain==1.2.0->-r requirements.txt (line 2)) (4.12.0)
# Requirement already satisfied: certifi in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain==1.2.0->-r requirements.txt (line 2)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain==1.2.0->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: idna in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain==1.2.0->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain==1.2.0->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: fsspec<2025.0.0,>=2024.9.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j==0.6.0->-r requirements.txt (line 10)) (2024.12.0)
# Requirement already satisfied: json-repair<0.45.0,>=0.44.1 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j==0.6.0->-r requirements.txt (line 10)) (0.44.1)
# Requirement already satisfied: pypdf<7.0.0,>=6.0.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j==0.6.0->-r requirements.txt (line 10)) (6.4.2)
# Requirement already satisfied: scipy<2.0.0,>=1.13.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j==0.6.0->-r requirements.txt (line 10)) (1.16.3)
# Requirement already satisfied: types-pyyaml<7.0.0.0,>=6.0.12.20240917 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain-neo4j==0.6.0->-r requirements.txt (line 10)) (6.0.12.20250915)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.0->langchain-classic==1.0.0->-r requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.0->langchain-classic==1.0.0->-r requirements.txt (line 4)) (2.6.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.0->-r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/alienorsabourdin/.pyenv/versions/3.12/envs/graphito/lib/python3.12/site-packages (from beautifulsoup4->wikipedia==1.4.0->-r requirements.txt (line 15)) (2.8)

# %% [markdown]
# ### Environment variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os


DIFFBOT_API_KEY = os.getenv("DIFFBOT_API_KEY")
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_DATABASE = os.getenv("NEO4J_DATABASE")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
NEO4J_USERNAME = os.getenv("NEO4J_USERNAME")

OLLAMA_BASE_URL = os.getenv("OLLAMA_BASE_URL")
OLLAMA_MODEL = os.getenv("OLLAMA_MODEL")

print("DIFFBOT_API_KEY:", bool(DIFFBOT_API_KEY))
print("NEO4J_URI:", NEO4J_URI)
print("NEO4J_DATABASE:", NEO4J_DATABASE)
print("NEO4J_PASSWORD:", NEO4J_PASSWORD)
print("NEO4J_PASSWORD:", NEO4J_USERNAME)
print("OLLAMA_BASE_URL:", OLLAMA_BASE_URL)
print("OLLAMA_MODEL:", OLLAMA_MODEL)


print(".env loaded correctly")
# Out:
# DIFFBOT_API_KEY: True
# NEO4J_URI: bolt://localhost:7687
# NEO4J_DATABASE: shop
# NEO4J_PASSWORD: password
# NEO4J_PASSWORD: neo4j
# OLLAMA_BASE_URL: http://localhost:11434
# OLLAMA_MODEL: llama3:8b
# .env loaded correctly

# %% [markdown]
# ## Extract graph content
# ### Load wikipedia documents

# %%
from langchain_community.document_loaders import WikipediaLoader

TOPIC = "Stray Kids"   
docs = WikipediaLoader(query=TOPIC, load_max_docs=2).load()

len(docs), docs[0].metadata, docs[0].page_content[:500]
# Out:
# (2,
#  {'title': 'Stray Kids',
#   'summary': 'Stray Kids (often abbreviated to SKZ; Korean: 스트레이 키즈; RR: Seuteurei Kijeu) is a South Korean boy band formed by JYP Entertainment. The band has eight members: Bang Chan, Lee Know, Changbin, Hyunjin, Han, Felix, Seungmin, and I.N. Former member Woojin left the band in 2019. Stray Kids primarily self-produces its recordings; the main production team is named 3Racha and consists of Bang Chan, Changbin, and Han, and the other members frequently participate in songwriting.\nThe leader, Bang Chan, personally selected each member to be a part of the band before filming the eponymous 2017 reality television show, which is unusual in K-pop, where that authority is usually held by the agency\'s executives and creative directors. The band released their unofficial debut extended play (EP) Mixtape in January 2018 and officially debuted on March 25 with the EP I Am Not, which was followed by the EPs I Am Who and I Am You, completing the I Am EP series. The Clé trilogy, consisting of Clé 1: Miroh, Clé 2: Yellow Wood, and Clé: Levanter, was released in 2019.\nThe band\'s first studio album, Go Live (2020), became its first platinum-certified album by the Korea Music Content Association (KMCA). That year, Stray Kids made their Japanese debut with the compilation album SKZ2020, which was released through Epic Records Japan. Their debut Japanese single, "Top", debuted atop the Oricon Singles Chart, making them the fourth foreign male artist to do so with their first single.\nIn 2021, Stray Kids\' second studio album, Noeasy, became its first million-selling album. After signing with Republic Records for promotions in the United States in 2022, the band released their EPs Oddinary, Maxident (both 2022), Rock-Star (2023), and Ate (2024); their studio albums 5-Star (2023) & Karma (2025); and their mixtapes Hop (2024) & Do It (2025). These eight releases peaked at number one on the US Billboard 200, making them the first act to debut at the top of the Billboard 200 with their first eight charted releases. The KMCA certified 5-Star five million in album sales, making Stray Kids the third group to achieve this in Korea. In 2023, the band appeared on Time\'s list of Next Generation Leaders. As of December 2024, Stray Kids has sold over 31 million albums, both Korean and Japanese releases.\n\n',
#   'source': 'https://en.wikipedia.org/wiki/Stray_Kids'},
#  'Stray Kids (often abbreviated to SKZ; Korean: 스트레이 키즈; RR: Seuteurei Kijeu) is a South Korean boy band formed by JYP Entertainment. The band has eight members: Bang Chan, Lee Know, Changbin, Hyunjin, Han, Felix, Seungmin, and I.N. Former member Woojin left the band in 2019. Stray Kids primarily self-produces its recordings; the main production team is named 3Racha and consists of Bang Chan, Changbin, and Han, and the other members frequently participate in songwriting.\nThe leader, Bang Chan, per')

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(chunk_size=1500, chunk_overlap=200)
split_docs = splitter.split_documents(docs)
len(split_docs), split_docs[0].page_content[:300]
# Out:
# (9,
#  'Stray Kids (often abbreviated to SKZ; Korean: 스트레이 키즈; RR: Seuteurei Kijeu) is a South Korean boy band formed by JYP Entertainment. The band has eight members: Bang Chan, Lee Know, Changbin, Hyunjin, Han, Felix, Seungmin, and I.N. Former member Woojin left the band in 2019. Stray Kids primarily self')

# %% [markdown]
# ### Extract graphs

# %%
from langchain_experimental.graph_transformers import DiffbotGraphTransformer

if not DIFFBOT_API_KEY:
    raise ValueError("Missing DIFFBOT_API_KEY env var. Set it locally; do not commit it.")

transformer = DiffbotGraphTransformer(diffbot_api_key=DIFFBOT_API_KEY)

graph_docs = transformer.convert_to_graph_documents(split_docs)
len(graph_docs), type(graph_docs[0])
# Out:
# (9, langchain_community.graphs.graph_document.GraphDocument)

# %%
#Display the graph extracted
gd = graph_docs[0]
gd.nodes[:5], gd.relationships[:5]
# Out:
# ([Node(id='http://www.wikidata.org/entity/Q59670293', type='Person', properties={'name': 'Bang Chan'}),
#   Node(id='http://www.wikidata.org/entity/Q46134670', type='Organization', properties={'name': 'Stray Kids'}),
#   Node(id='Woojin', type='Person', properties={'name': 'Woojin'})],
#  [Relationship(source=Node(id='http://www.wikidata.org/entity/Q59670293', type='Person', properties={}), target=Node(id='http://www.wikidata.org/entity/Q46134670', type='Organization', properties={}), type='EMPLOYEE_OR_MEMBER_OF', properties={'evidence': 'Stray Kids primarily self-produces its recordings; the main production team is named 3Racha and consists of Bang Chan, Changbin, and Han, and the other members frequently participate in songwriting.', 'isCurrent': 'true'}),
#   Relationship(source=Node(id='Woojin', type='Person', properties={}), target=Node(id='http://www.wikidata.org/entity/Q46134670', type='Organization', properties={}), type='EMPLOYEE_OR_MEMBER_OF', properties={'evidence': 'Stray Kids primarily self-produces its recordings; the main production team is named 3Racha and consists of Bang Chan, Changbin, and Han, and the other members frequently participate in songwriting.', 'isCurrent': 'true'})])

# %% [markdown]
# ## Neo4j

# %% [markdown]
# ### Connect and build the graphs

# %%
from neo4j import GraphDatabase

driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

def run_cypher(q, params=None):
    params = params or {}
    with driver.session(database=NEO4J_DATABASE) as s:
        return list(s.run(q, params))

# ⚠️ Clean DB
run_cypher("MATCH (n) DETACH DELETE n")
run_cypher("SHOW DATABASES")
# Out:
# [<Record name='shop' type='standard' aliases=[] access='read-write' address='localhost:7687' role='primary' writer=True requestedStatus='online' currentStatus='online' statusMessage='' default=True home=True constituents=[]>,
#  <Record name='system' type='system' aliases=[] access='read-write' address='localhost:7687' role='primary' writer=True requestedStatus='online' currentStatus='online' statusMessage='' default=False home=False constituents=[]>]

# %%
from langchain_neo4j import Neo4jGraph

graph = Neo4jGraph(
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD,
    database=NEO4J_DATABASE
)

graph.add_graph_documents(graph_docs)

graph.refresh_schema()
print(graph.schema)
# Out:
# Node properties:
# Person {id: STRING, name: STRING}
# Organization {id: STRING, name: STRING}
# Location {id: STRING, name: STRING}
# Relationship properties:
# EMPLOYEE_OR_MEMBER_OF {evidence: STRING, isCurrent: STRING}
# WORK_RELATIONSHIP {evidence: STRING}
# FOUNDED_BY {evidence: STRING}
# ORGANIZATION_LOCATIONS {evidence: STRING}
# The relationships:
# (:Person)-[:EMPLOYEE_OR_MEMBER_OF]->(:Organization)
# (:Person)-[:WORK_RELATIONSHIP]->(:Person)
# (:Organization)-[:ORGANIZATION_LOCATIONS]->(:Location)
# (:Organization)-[:FOUNDED_BY]->(:Person)

# %% [markdown]
# ### Inspect graphs with cypher

# %%
run_cypher("CALL db.labels() YIELD label RETURN label ORDER BY label")
# Out:
# [<Record label='Location'>,
#  <Record label='Organization'>,
#  <Record label='Person'>]

# %%
run_cypher("CALL db.relationshipTypes() YIELD relationshipType RETURN relationshipType ORDER BY relationshipType")
# Out:
# [<Record relationshipType='EMPLOYEE_OR_MEMBER_OF'>,
#  <Record relationshipType='FOUNDED_BY'>,
#  <Record relationshipType='ORGANIZATION_LOCATIONS'>,
#  <Record relationshipType='WORK_RELATIONSHIP'>]

# %%
run_cypher("MATCH (n) RETURN labels(n) as labels, n.name as name, n.id as id LIMIT 25")
# Out:
# [<Record labels=['Person'] name='Bang Chan' id='http://www.wikidata.org/entity/Q59670293'>,
#  <Record labels=['Organization'] name='Stray Kids' id='http://www.wikidata.org/entity/Q46134670'>,
#  <Record labels=['Person'] name='Woojin' id='Woojin'>,
#  <Record labels=['Person'] name='Felix' id='Felix'>,
#  <Record labels=['Person'] name='Lee Know' id='http://www.wikidata.org/entity/Q59260597'>,
#  <Record labels=['Location'] name='Japan' id='http://www.wikidata.org/entity/Q17'>]

# %%
run_cypher("""
MATCH (p)
WHERE (p.name IS NOT NULL AND toLower(p.name) CONTAINS toLower($name))
   OR (p.id   IS NOT NULL AND toLower(p.id)   CONTAINS toLower($name))
WITH p LIMIT 5
MATCH (p)-[r]-(o)
RETURN labels(p) AS pLabels, p.name AS pName,
       type(r) AS rel, labels(o) AS oLabels, o.name AS oName
LIMIT 50
""", {"name": "Stray Kids"})
# Out:
# [<Record pLabels=['Organization'] pName='Stray Kids' rel='ORGANIZATION_LOCATIONS' oLabels=['Location'] oName='Japan'>,
#  <Record pLabels=['Organization'] pName='Stray Kids' rel='FOUNDED_BY' oLabels=['Person'] oName='Bang Chan'>,
#  <Record pLabels=['Organization'] pName='Stray Kids' rel='EMPLOYEE_OR_MEMBER_OF' oLabels=['Person'] oName='Woojin'>,
#  <Record pLabels=['Organization'] pName='Stray Kids' rel='EMPLOYEE_OR_MEMBER_OF' oLabels=['Person'] oName='Bang Chan'>]

# %%
run_cypher("""
MATCH (p)
WHERE p.name IS NOT NULL AND toLower(p.name) CONTAINS toLower($name)
WITH p, COUNT {(p)--()} AS degree
RETURN p.name AS name, labels(p) AS labels, p.id AS id, degree
ORDER BY degree DESC
LIMIT 10
""", {"name":"Stray Kids"})
# Out:
# [<Record name='Stray Kids' labels=['Organization'] id='http://www.wikidata.org/entity/Q46134670' degree=4>]

# %% [markdown]
# ## Function to get all relationships for an entity

# %%
def get_person_relationships(person_name: str, limit_nodes: int = 1, limit_edges: int = 200):
    q = """
    MATCH (p)
    WHERE (p.name IS NOT NULL AND toLower(p.name) CONTAINS toLower($name))
    WITH p, COUNT {(p)--()} AS degree
    ORDER BY degree DESC
    LIMIT $limit_nodes
    MATCH (p)-[r]-(o)
    RETURN p.name AS person, labels(p) AS personLabels,
           type(r) AS rel, o.name AS other, labels(o) AS otherLabels,
           properties(r) AS relProps, properties(o) AS otherProps
    LIMIT $limit_edges
    """
    return run_cypher(q, {"name": person_name, "limit_nodes": limit_nodes, "limit_edges": limit_edges})

rows = get_person_relationships("Stray Kids")
rows[:3]
# Out:
# [<Record person='Stray Kids' personLabels=['Organization'] rel='ORGANIZATION_LOCATIONS' other='Japan' otherLabels=['Location'] relProps={'evidence': 'Stray Kids debuted in Japan with the Japanese version of "Levanter", "Double Knot", and "My Pace", as well as the re-recorded version of their songs from the previous album compiled in the compilation album SKZ2020.'} otherProps={'id': 'http://www.wikidata.org/entity/Q17', 'name': 'Japan'}>,
#  <Record person='Stray Kids' personLabels=['Organization'] rel='FOUNDED_BY' other='Bang Chan' otherLabels=['Person'] relProps={'evidence': "It was later revealed that the Stray Kids' member line-up was formed unusually, with the leader Bang Chan handpicking each member from the list of JYPE trainees rather than the agency's executives and creative directors selecting them."} otherProps={'id': 'http://www.wikidata.org/entity/Q59670293', 'name': 'Bang Chan'}>,
#  <Record person='Stray Kids' personLabels=['Organization'] rel='EMPLOYEE_OR_MEMBER_OF' other='Woojin' otherLabels=['Person'] relProps={'evidence': 'Stray Kids primarily self-produces its recordings; the main production team is named 3Racha and consists of Bang Chan, Changbin, and Han, and the other members frequently participate in songwriting.', 'isCurrent': 'true'} otherProps={'id': 'Woojin', 'name': 'Woojin'}>]

# %% [markdown]
# ## Ollama

# %% [markdown]
# ### Setting up the model

# %% [markdown]
# Create the llm

# %%
from langchain_community.chat_models import ChatOllama

llm = ChatOllama(
    model=OLLAMA_MODEL,
    base_url=OLLAMA_BASE_URL,
    temperature=0
)
# Out:
# /var/folders/qm/m2j4gyxn6d3dvqq5n3d91kxr0000gn/T/ipykernel_72641/2864514228.py:3: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import ChatOllama``.
#   llm = ChatOllama(

# %% [markdown]
# Write the cypher prompt

# %%
import langchain_neo4j, pkgutil
[c.name for c in pkgutil.iter_modules(langchain_neo4j.__path__)]
# Out:
# ['chains',
#  'chat_message_histories',
#  'graphs',
#  'query_constructors',
#  'vectorstores']

# %%
from langchain_community.graphs import Neo4jGraph as ClassicNeo4jGraph
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import GraphCypherQAChain
from langchain_core.prompts import PromptTemplate

CYPHER_PROMPT = PromptTemplate.from_template("""
You are a Neo4j Cypher expert.

Rules:
- Use ONLY the schema below.
- Always match entities using the `name` property.
- type(r) is ONLY for relationships.
- labels(n) is ONLY for nodes.
- Never call type() on a node.
- Prefer exact match when the name is known.

Schema:
{schema}

Question:
{question}

Cypher query:
""")


qa_chain = GraphCypherQAChain.from_llm(
    llm=llm,
    graph=classic_graph,
    cypher_prompt=CYPHER_PROMPT,
    verbose=True,
    allow_dangerous_requests=True,
    validate_cypher=True,
    top_k=20
)

# %% [markdown]
# Useful function in our case

# %%
def ask_graph(question: str, debug: bool = True) -> str:
    out = qa_chain.invoke({"query": question})
    if debug:
        print("Cypher:\n", out.get("cypher", "<no cypher returned>"))
        print("\nRaw result keys:", list(out.keys()))
    return out.get("result", out)


ask_graph("What are the main entities connected to Stray Kids?")
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
#
# MATCH (n:Person {name: "Stray Kids"})-[:EMPLOYEE_OR_MEMBER_OF]-(o:Organization)
# OPTIONAL MATCH (o)-[:ORGANIZATION_LOCATIONS]-(loc:Location)
# RETURN o, loc
#
# Full Context:
# []
#
# > Finished chain.
# Cypher:
#  <no cypher returned>
#
# Raw result keys: ['query', 'result']
# "I don't know the answer."

# %% [markdown]
# ### Subgraph retrieval

# %%
def get_entity_subgraph(entity_name: str, hops: int = 1, limit_edges: int = 120):
    # 1-hop neighborhood (simple + reliable)
    q = """
    MATCH (p)
    WHERE p.name IS NOT NULL AND toLower(p.name) CONTAINS toLower($name)
    WITH p, COUNT{(p)--()} AS degree
    ORDER BY degree DESC
    LIMIT 1
    MATCH (p)-[r]-(o)
    RETURN p.name AS center,
           type(r) AS rel,
           coalesce(o.name, o.id, 'UNKNOWN') AS neighbor,
           labels(o) AS neighborLabels,
           properties(r) AS relProps
    LIMIT $limit_edges
    """
    return run_cypher(q, {"name": entity_name, "limit_edges": limit_edges})

# %%
from langchain_core.messages import HumanMessage

def summarize_entity(entity_name: str):
    edges = get_entity_subgraph(entity_name)
    # Convert to compact bullet evidence
    evidence = []
    for e in edges:
        evidence.append(f"- ({e['center']}) -[:{e['rel']}]-> ({e['neighborLabels']} {e['neighbor']}) props={e['relProps']}")
    evidence_text = "\n".join(evidence[:80])  # keep prompt small-ish

    prompt = f"""
You are summarizing an entity using ONLY the evidence below from a Neo4j graph.
If a fact (especially dates/numbers) is not explicitly present in evidence, say "not present in the graph evidence".
Do not add outside knowledge.
Write 6-10 bullet points.

Entity: {entity_name}

Evidence:
{evidence_text}
"""
    resp = llm.invoke([HumanMessage(content=prompt)])
    return resp.content

print(summarize_entity("Stray Kids"))
# Out:
# Here are 7 bullet points summarizing Stray Kids based on the provided Neo4j graph evidence:
#
# • Stray Kids debuted in Japan with the Japanese versions of "Levanter", "Double Knot", and "My Pace", as well as a compilation album SKZ2020.
# • The group was founded by Bang Chan, who handpicked each member from JYPE trainees rather than agency executives and creative directors selecting them.
# • Stray Kids is primarily self-producing, with the main production team being 3Racha, consisting of Bang Chan, Changbin, and Han.
# • Other members frequently participate in songwriting for the group's recordings.
# • Woojin is a member of Stray Kids.
# • Bang Chan is a member of Stray Kids and also the founder of the group.
# • The location where Stray Kids debuted is Japan.
